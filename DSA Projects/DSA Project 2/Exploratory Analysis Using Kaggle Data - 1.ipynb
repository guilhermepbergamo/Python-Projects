# %% [markdown]
# ##  Exploratory Analysis Using Kaggle Data
#
# ## First Analysis

# %%
#Python version
from platform import python_version
print('Used Python version:', python_version())
# Out:
# Used Python version: 3.9.7

# %%
# Imports
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mat
import matplotlib.pyplot as plt
from datetime import datetime
sns.set(style="white")
# %matplotlib inline

# %%
np.__version__
# Out:
# '1.20.3'

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
mat.__version__
# Out:
# '3.4.3'

# %%
# Dataset
clean_data_path = "dataset/autos.csv"
df = pd.read_csv(clean_data_path,encoding="latin-1")

# %% [markdown]
# ## Distribution of Vehicles based on Year of Registration

# %%
# Creating a Plot with Vehicle Distribution based on Year of Registration
fig, ax = plt.subplots(figsize=(8,6))
sns.histplot(df["yearOfRegistration"], color="#33cc33",kde=True, ax=ax)
ax.set_title('Distribution of Vehicles based on Year of Registration', fontsize= 15)
plt.ylabel("Density (KDE)", fontsize= 15)
plt.xlabel("Year of Registration", fontsize= 15)
plt.show()

# %%
# Saving the plot
fig.savefig("plots/Analise1/vehicle-distribution.png")

# %% [markdown]
# ## Price range variation by vehicle type

# %%
# Creating a Boxplot to Evaluate Outliers
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x="vehicleType", y="price", data=df)
ax.text(5.25,27000,"Outliers Analysis",fontsize=18,color="r",ha="center", va="center")
ax.xaxis.set_label_text("Vehicle Type",fontdict= {'size':14})
ax.yaxis.set_label_text("Price Range",fontdict= {'size':14})
plt.show()

# %%
# Saving the plot
fig.savefig("plots/Analise1/price-vehicleType-boxplot.png")

# %% [markdown]
# ## Total count of vehicles for sale by vehicle type

# %%
# Creating a Count Plot that shows the number of vehicles belonging to each category
sns.set_style("white")
g = sns.catplot(x="vehicleType", data=df, kind="count", palette="BuPu", height=6, aspect=1.5)
g.ax.xaxis.set_label_text("Vehicle Type",fontdict= {'size':16})
g.ax.yaxis.set_label_text("Total Vehicles For Sale", fontdict= {'size':16})
g.ax.set_title("Total count of vehicles for sale by vehicle type",fontdict= {'size':18})
# to get the counts on the top heads of the bar
for p in g.ax.patches:
    g.ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+500))

# %%
# Saving the plot
g.savefig("plots/Analise1/count-vehicleType.png")

# %% [markdown]
# # The End
